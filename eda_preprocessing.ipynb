# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('data/car_details.csv') #read the csv file into the python environment as a pandas dataFrame

# %%
df.head() #returns first 5 rows
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0    Volvo XC90 T8 Excellence BSIV  2017       10000000      30000  Petrol
# 1  Mercedes-Benz S-Class S 350 CDI  2017        5850000      47000  Diesel
# 2  Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000  Petrol
# 3  Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000  Petrol
# 4  Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000  Petrol
#
#   seller_type transmission        owner  mileage  engine  max_power  \
# 0  Individual    Automatic  First Owner     42.0  1969.0      400.0
# 1      Dealer    Automatic  First Owner     13.5  2987.0      282.0
# 2  Individual    Automatic  First Owner      9.5  3604.0      280.0
# 3  Individual    Automatic  First Owner      9.5  3604.0      280.0
# 4  Individual    Automatic  First Owner      9.5  3604.0      280.0
#
#            torque  seats
# 0  640Nm@ 1740rpm    4.0
# 1  490Nm@ 1600rpm    5.0
# 2  347Nm@ 4300rpm    5.0
# 3  347Nm@ 4300rpm    5.0
# 4  347Nm@ 4300rpm    5.0

# %%
df.tail() #return the last 5 rows
# Out:
#                                       name  year  selling_price  km_driven  \
# 8123                Toyota Qualis Fleet A3  2000         200000     100000
# 8124             Hyundai Santro LS zipPlus  2000         140000      50000
# 8125  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8126             Ford Figo Aspire Facelift  2017         580000     165000
# 8127                  Maruti Swift 1.3 VXi  2006         130000     100000
#
#         fuel seller_type transmission         owner  mileage  engine  \
# 8123  Diesel  Individual       Manual   First Owner      NaN     NaN
# 8124  Petrol  Individual       Manual  Second Owner      NaN     NaN
# 8125  Petrol  Individual       Manual  Second Owner      NaN     NaN
# 8126  Diesel  Individual       Manual   First Owner      NaN     NaN
# 8127  Petrol  Individual       Manual  Second Owner      NaN     NaN
#
#       max_power torque  seats
# 8123        NaN    NaN    NaN
# 8124        NaN    NaN    NaN
# 8125        NaN    NaN    NaN
# 8126        NaN    NaN    NaN
# 8127        NaN    NaN    NaN

# %%
#shape of the dataset
print(f'- {df.shape[0]} rows') #returns the number of rows in the dataset
print(f'- {df.shape[1]} columns') #returns the number of columns in the dataset
# Out:
# - 8128 rows
# - 13 columns

# %%
#summary statistics
df.info() #returns column names, non-null count and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   float64
#  9   engine         7907 non-null   float64
#  10  max_power      7912 non-null   float64
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 825.6+ KB

# %%
#descriptive statistics of the datset 
df.describe(include='all').T
# Out:
#                 count unique                     top  freq           mean  \
# name             8128   2058  Maruti Swift Dzire VDI   129            NaN
# year           8128.0    NaN                     NaN   NaN    2013.804011
# selling_price  8128.0    NaN                     NaN   NaN  638271.807702
# km_driven      8128.0    NaN                     NaN   NaN   69819.510827
# fuel             8128      4                  Diesel  4402            NaN
# seller_type      8128      3              Individual  6766            NaN
# transmission     8128      2                  Manual  7078            NaN
# owner            8128      5             First Owner  5289            NaN
# mileage        7907.0    NaN                     NaN   NaN      19.418783
# engine         7907.0    NaN                     NaN   NaN    1458.625016
# max_power      7912.0    NaN                     NaN   NaN      91.517919
# torque           7906    441          190Nm@ 2000rpm   530            NaN
# seats          7907.0    NaN                     NaN   NaN       5.416719
#
#                          std      min       25%       50%       75%  \
# name                     NaN      NaN       NaN       NaN       NaN
# year                4.044249   1983.0    2011.0    2015.0    2017.0
# selling_price  806253.403508  29999.0  254999.0  450000.0  675000.0
# km_driven       56550.554958      1.0   35000.0   60000.0   98000.0
# fuel                     NaN      NaN       NaN       NaN       NaN
# seller_type              NaN      NaN       NaN       NaN       NaN
# transmission             NaN      NaN       NaN       NaN       NaN
# owner                    NaN      NaN       NaN       NaN       NaN
# mileage             4.037145      0.0     16.78      19.3     22.32
# engine            503.916303    624.0    1197.0    1248.0    1582.0
# max_power          35.822499      0.0     68.05      82.0     102.0
# torque                   NaN      NaN       NaN       NaN       NaN
# seats               0.959588      2.0       5.0       5.0       5.0
#
#                       max
# name                  NaN
# year               2020.0
# selling_price  10000000.0
# km_driven       2360457.0
# fuel                  NaN
# seller_type           NaN
# transmission          NaN
# owner                 NaN
# mileage              42.0
# engine             3604.0
# max_power           400.0
# torque                NaN
# seats                14.0

# %%
#selecting categorical and numerical columns
categorical_cols = df.select_dtypes(include='object').columns #returns categorical columns only
numerical_cols = df.select_dtypes(include='number').columns #returns numerical columns only

# %%
cols = [col for col in categorical_cols] #a list comprehension, making a list of categorical columns
print(f'This dataset has {len(cols)} categorical columns - {cols}') #returns the number of categorical columns
# Out:
# This dataset has 6 categorical columns - ['name', 'fuel', 'seller_type', 'transmission', 'owner', 'torque']

# %%
for cols in categorical_cols: #loop through categorical columns
    print(f' - {cols} : {df[cols].unique()} - {df[cols].nunique()}\n') #returns column names, unique values and number of unique values
# Out:
#  - name : ['Volvo XC90 T8 Excellence BSIV' 'Mercedes-Benz S-Class S 350 CDI'
#  'Jeep Wrangler 2016-2019 3.6 4X4' ... 'Hyundai Santro Xing ABS'
#  'Hyundai Santro Xing XO' 'Hyundai Accent Gvs'] - 2058
#
#  - fuel : ['Petrol' 'Diesel' 'CNG' 'LPG'] - 4
#
#  - seller_type : ['Individual' 'Dealer' 'Trustmark Dealer'] - 3
#
#  - transmission : ['Automatic' 'Manual'] - 2
#
#  - owner : ['First Owner' 'Third Owner' 'Second Owner' 'Fourth & Above Owner'
#  'Test Drive Car'] - 5
#
#  - torque : ['640Nm@ 1740rpm' '490Nm@ 1600rpm' '347Nm@ 4300rpm' '355Nm@ 4500rpm'
#  '600Nm@ 2000rpm' '620Nm@ 1500-2500rpm' '620Nm@ 2000-2500rpm'
#  '560Nm@ 1500rpm' '619Nm@ 1600-2400rpm' '620Nm@ 1600-2400rpm'
#  '580Nm@ 1400-3250rpm' '550Nm@ 1750-2750rpm' '540Nm@ 2000rpm'
#  '51@ 1,750-3,000(kgm@ rpm)' '53@ 2,000-2,750(kgm@ rpm)' '480Nm'
#  '510Nm@ 1600-2800rpm' '196Nm@ 5000rpm' '450Nm@ 1750-2500rpm'
#  '202Nm@ 3600-5200rpm' '245Nm@ 5000rpm' '500Nm@ 1600-1800rpm'
#  '46.5@ 1,400-2,800(kgm@ rpm)' '250Nm@ 4250rpm' '500Nm@ 2000rpm'
#  '470Nm@ 1750-2500rpm' '300Nm@ 1600-4000rpm' '420.7Nm@ 1800-2500rpm'
#  '436.39Nm@ 1800-2500rpm' '436.4Nm@ 1800-2500rpm' '400nm@ 2800rpm'
#  '400nm@ 1750-2500rpm' '400Nm@ 1750-2500rpm' '400Nm@ 1750-2750rpm' '400Nm'
#  '250Nm@ 1250-5300rpm' '280Nm@ 1350-4600rpm' '400nm@ 1750-3000rpm'
#  '380Nm@ 1750-2750rpm' '400Nm@ 1750-3000rpm' '320Nm@ 1400-4100rpm'
#  '450Nm@ 2000rpm' '420Nm@ 2000rpm' '226Nm@ 4400rpm' '285Nm@ 2400-4000rpm'
#  '402Nm@ 1600-3000rpm' '424Nm@ 2000rpm' '400Nm@ 175-2750rpm'
#  '300Nm@ 1200-4000rpm' '300Nm@ 1200-1400rpm' '380Nm@ 1750-3000rpm'
#  '380Nm@ 1750rpm' '228Nm@ 4400rpm' '400Nm@ 2000-2500rpm'
#  '24.5@ 3,500-4,500(kgm@ rpm)' '222Nm@ 4300rpm' '250Nm@ 1250-5000rpm'
#  '250@ 1250-5000rpm' '430Nm@ 1750-2500rpm' '35.7@ 1,750-3,000(kgm@ rpm)'
#  '350Nm@ 1500-3500rpm' '380NM@ 1800-2800rpm' '450Nm@ 1600-2400rpm'
#  '420Nm@ 1400-2600rpm' '380Nm@ 1750-2500rpm' '360Nm@ 1200-3400rpm'
#  '343Nm@ 1400-3400rpm' '350Nm@ 1750-2500rpm' '410Nm@ 1600-2800rpm'
#  '42@ 2,000(kgm@ rpm)' '400Nm@ 1400-2800rpm' '360Nm@ 1400-3200rpm'
#  '510@ 1600-2400' '23.6@ 4,250(kgm@ rpm)' '224Nm@ 4000rpm'
#  '245Nm@ 4000rpm' '380Nm@ 2000rpm' '360Nm@ 2000rpm'
#  '22.9@ 1,950-4,700(kgm@ rpm)' '340Nm@ 1800-3250rpm' '333Nm@ 1600-3200rpm'
#  '250Nm@ 1750-2500rpm' '250Nm@ 1500~4500rpm' '218Nm@ 4200rpm'
#  '385Nm@ 1600-2500rpm' '250Nm@ 1500-4500rpm' '213Nm@ 4500rpm'
#  '380Nm(38.7kgm)@ 2500rpm' '360Nm@ 1750-2800rpm' '380Nm@ 2500rpm'
#  '190Nm@ 4300rpm' '215Nm@ 3600rpm' '250 Nm at 2750 rpm' '32.1kgm@ 2000rpm'
#  '350Nm@ 1500-2750rpm' '21.4@ 1,750-4,600(kgm@ rpm)' '382nm@ 1750-2250rpm'
#  '320Nm@ 1700-2700rpm' '320Nm@ 2000rpm' '340nm@ 1750-3000rpm'
#  '320Nm@ 1500-3000rpm' '350nm@ 1800-2600rpm' '327Nm@ 2600rpm'
#  '343Nm@ 1400-2800rpm' '360Nm@ 1400-2600rpm' '320Nm@ 1750-2500rpm'
#  '177.5Nm@ 4700rpm' '20@ 4,700(kgm@ rpm)' '33.7@ 1,800(kgm@ rpm)'
#  '320Nm@ 1750-3000rpm' '343Nm@ 1600-2800rpm' '33@ 2,000-2,680(kgm@ rpm)'
#  '190Nm@ 4200rpm' '330Nm@ 1800rpm' '250Nm@ 1600-3600rpm'
#  '320Nm@ 1500-2800rpm' '330Nm@ 1600-2800rpm' '320Nm@ 1600-2800rpm'
#  '36.6@ 1,750-2,500(kgm@ rpm)' '174Nm@ 4300rpm' '321Nm@ 1600-2400rpm'
#  '173Nm@ 4000rpm' '320Nm@ 1750-2700rpm' '300Nm@ 1600-3000rpm'
#  '190Nm@ 3700rpm' '320Nm@ 1800-2800rpm' '17.5@ 4,300(kgm@ rpm)'
#  '170Nm@ 4200rpm' '172Nm@ 4300rpm' '20@ 3,750(kgm@ rpm)'
#  '16.6@ 4,500(kgm@ rpm)' '259.8Nm@ 1900-2750rpm' '259.9Nm@ 1900-2750rpm'
#  '259.87Nm@ 1900-2750rpm' '259.88Nm@ 1900-2750rpm'
#  '259.87nm@ 1500-3000rpm' '259.87NM@ 1500-3000rpm' '16.1@ 4,200(kgm@ rpm)'
#  '305Nm@ 2000rpm' '170Nm@ 1400-4500rpm' '21.4@ 1,900(kgm@ rpm)'
#  '154.9Nm@ 4200rpm' '150Nm@ 4500rpm' '151Nm@ 4850rpm' '151NM@ 4850rpm'
#  '300Nm@ 1750-2500rpm' '200Nm@ 1250-4000rpm' '149Nm@ 4500rpm'
#  '290Nm@ 1800-2800rpm' '280Nm@ 1800-2800rpm' '25.5@ 1,500-3,000(kgm@ rpm)'
#  '250 Nm at 1,500-3,000 rpm' '250Nm@ 1500-3000rpm' '171.6Nm@ 1500-4000rpm'
#  '280Nm@ 2400-2800rpm' '300Nm@ 2000rpm' '146Nm at 4800 rpm'
#  '145Nm@ 4600rpm' '292Nm@ 2000rpm' '28.3@ 1,700-2,200(kgm@ rpm)'
#  '146Nm@ 4800rpm' '277.5Nm@ 1700-2200rpm' '400 Nm /2000 rpm'
#  '300Nm@ 1500-2500rpm' '250nm@ 1500-2750rpm' '144.15nm@ 4500rpm'
#  '250.06nm@ 1500-2750rpm' '25@ 1,800-2,800(kgm@ rpm)'
#  '260 Nm at 1800-2200 rpm' '260Nm@ 1800-2200rpm' '136Nm@ 4250rpm'
#  '140Nm@ 4400rpm' '24@ 1,900-2,750(kgm@ rpm)' '24 KGM at 1900-2750 RPM'
#  '200Nm@ 2000-3500rpm' '250Nm@ 1500-2500rpm' '175nm@ 1750-4000rpm'
#  '250nm@ 1500-3000rpm' '260Nm@ 1500-2750rpm' '240Nm@ 1750rpm'
#  '240Nm@ 1850rpm' '245Nm@ 1750rpm' '248Nm@ 2250rpm' '123Nm@ 1000-2500rpm'
#  '170Nm@ 1750-4000rpm' '25.5@ 1,900(kgm@ rpm)' '140Nm@ 4200rpm'
#  '135.3Nm@ 5000rpm' '263.7Nm@ 2500rpm' '247Nm@ 1800-2000rpm'
#  '153Nm@ 3800rpm' '145@ 4,100(kgm@ rpm)' '142Nm@ 4000rpm' '148Nm@ 3500rpm'
#  '175Nm@ 1500-4100rpm' '145Nm@ 4100rpm' '138nm@ 4400rpm' '138Nm@ 4400rpm'
#  '175nm@ 1500-4100rpm' '14.9 KGM at 3000 RPM' '14.9@ 3,000(kgm@ rpm)'
#  '153Nm@ 3750-3800rpm' '145Nm@ 3750rpm' '148Nm@ 4000rpm'
#  '20.4@ 1400-3400(kgm@ rpm)' '15@ 3,800(kgm@ rpm)' '14.9@ 3,400(kgm@ rpm)'
#  '200Nm@ 1200-3600rpm' '200Nm@ 1400-3400rpm' '150Nm@ 1700-4500rpm'
#  '13.5@ 4,800(kgm@ rpm)' '240Nm@ 1600-2800rpm' '230Nm@ 1500-2250rpm'
#  '13.1kgm@ 4600rpm' '13.9 kgm at 4200 rpm' '146Nm@ 3400rpm'
#  '134Nm@ 4000rpm' '124Nm@ 3500rpm' '215Nm@ 1750-3000rpm'
#  '215Nm@ 1750-3000' '215nm@ 1750-2500rpm' '215Nm@ 1750-2500rpm'
#  '205Nm@ 1750-3250rpm' '131Nm@ 4400rpm' '200Nm@ 1750rpm'
#  '132.3Nm@ 4000rpm' '136.3Nm@ 4200rpm' '220Nm at 1400-2600 rpm'
#  '120Nm@ 4250rpm' '119Nm@ 4250rpm' '12.5kgm@ 3500rpm' '130Nm@ 3000rpm'
#  '12.5@ 3,500(kgm@ rpm)' '225Nm@ 1500-2500rpm' '218Nm@ 1400-2600rpm'
#  '124.6Nm@ 3500rpm' '124.5Nm@ 3500rpm' '130Nm@ 4000rpm' '127Nm@ 3500rpm'
#  '130@ 2500(kgm@ rpm)' '209Nm@ 2000rpm' '190Nm@ 2000-3000'
#  '190@ 21,800(kgm@ rpm)' '190Nm@ 2000-3000rpm' '204Nm@ 2000-2750rpm'
#  '22.4 kgm at 1750-2750rpm' '115Nm@ 4500rpm' '116Nm@ 4750rpm'
#  '11.3kgm@ 4700rpm' '200Nm@ 1750-3000rpm' '110(11.2)@ 4800'
#  '230Nm@ 1500-2500rpm' '219.7Nm@ 1500-2750rpm' '110Nm@ 4800rpm'
#  '219.66NM@ 1500-2750rpm' '224nm@ 1500-2750rpm' '219.66nm@ 1500-2750rpm'
#  '219.6Nm@ 1500-2750rpm' '219.6Nm@ 1750-2750rpm' '132Nm@ 3000rpm'
#  '220Nm@ 1500-2750rpm' '219.7Nm@ 1750-2750rpm' '219.9Nm@ 1750-2750rpm'
#  '190Nm@ 1750-3000rpm' '140Nm@ 1500-4000rpm' '113Nm@ 4400rpm'
#  '113nm@ 4400rpm' '11.5@ 4,500(kgm@ rpm)' '205Nm@ 1800-2800rpm'
#  '109Nm@ 4500rpm' '112Nm@ 4000rpm' '128Nm@ 3100rpm' '114Nm@ 4000rpm'
#  '12@ 3,500(kgm@ rpm)' '110Nm@ 4500rpm' '113Nm@ 4,500rpm' '200Nm@ 2000rpm'
#  '113Nm@ 5000rpm' '113Nm@ 3300rpm' '114Nm@ 3500rpm' '250Nm@ 1000-2000rpm'
#  '200Nm@ 1900rpm' '115Nm@ 4000rpm' '113Nm@ 4200rpm' '250Nm@ 1600-2000rpm'
#  '176Nm@ 1500rpm' '115Nm@ 3200rpm' '11.8@ 3,200(kgm@ rpm)'
#  '113.8Nm@ 4000rpm' '113.7Nm@ 4000rpm' '108.5Nm@ 5000rpm' '187Nm@ 2500rpm'
#  '115Nm@ 3500-3600rpm' '113.75Nm@ 4000rpm' '113.75nm@ 4000rpm'
#  '117nm@ 4000rpm' '114.73nm@ 4000rpm' '114.73Nm@ 4000rpm'
#  '114.7Nm@ 4000rpm' '110Nm@ 4000rpm' '230Nm@ 1800-2000rpm'
#  '19@ 1,800(kgm@ rpm)' '103Nm@ 4500rpm' '11.4@ 4,000(kgm@ rpm)'
#  '11.4 kgm at 4,000 rpm' '108Nm@ 4400rpm' '160Nm@ 1750rpm'
#  '111.7Nm@ 4000rpm' '111.8Nm@ 4000rpm' '104Nm@ 3100rpm'
#  '12.7@ 2,700(kgm@ rpm)' '240Nm@ 2000rpm' '121Nm@ 2800rpm'
#  '190Nm@ 1750-2250rpm' '205Nm@ 1750rpm' '106.5Nm@ 4400rpm'
#  '104Nm@ 4400rpm' '104Nm@ 4000rpm' '11.2@ 4,400(kgm@ rpm)'
#  '200Nm@ 1400-2200rpm' '151Nm@ 2400rpm' '185Nm@ 1750-2750rpm'
#  '11@ 3,000(kgm@ rpm)' '110@ 3,000(kgm@ rpm)' '110Nm@ 3000rpm'
#  '197Nm@ 1750rpm' '190 Nm at 2000rpm' '190 Nm at 1750 rpm '
#  '190Nm@ 1750rpm' '190 Nm at 1750  rpm ' '190 Nm at 1750 rpm'
#  '190Nm@ 2000rpm' '180Nm@ 2000rpm' '180 Nm at 2000rpm' '110Nm@ 3750rpm'
#  '95Nm@ 3000-4300rpm' '210nm@ 1600-2200rpm' '110Nm@ 4400rpm'
#  '110Nm@ 3000-4300rpm' '190.25nm@ 1750-2250rpm' '190.24nm@ 1750-2250rpm'
#  '113Nm@ 4500rpm' '172.5Nm@ 1750rpm' '101Nm@ 3000rpm' '171Nm@ 1800rpm'
#  '96Nm@ 3500rpm' '180.4Nm@ 1750-2500rpm' '135 Nm at 2500 rpm'
#  '135 Nm at 2500  rpm ' '135Nm@ 2500rpm' '195Nm@ 1400-2200rpm'
#  '155 Nm at 1600-2800 rpm' '135.4Nm@ 2500' '135.4Nm@ 2500rpm'
#  '13.5@ 2500(kgm@ rpm)' '13.5@ 2,500(kgm@ rpm)'
#  '14.3@ 1,800-3,000(kgm@ rpm)' '140Nm@ 1800-3000rpm'
#  '12.4@ 2,600(kgm@ rpm)' '10.7@ 2,500(kgm@ rpm)' '102Nm@ 4000rpm'
#  '160Nm@ 1500-2750rpm' '159.8Nm@ 1500-2750rpm' '223Nm@ 1600-2200rpm'
#  '160Nm@ 2000rpm' '99.1Nm@ 4500rpm' '99.07Nm@ 4500rpm' '99.04Nm@ 4500rpm'
#  '94.14Nm@ 3500rpm' '12.5@ 3,000(kgm@ rpm)' '115@ 2500(kgm@ rpm)'
#  '115@ 2,500(kgm@ rpm)' '12@ 2500(kgm@ rpm)' '13@ 2,500(kgm@ rpm)'
#  '16.3@ 2,000(kgm@ rpm)' '16@ 2,000(kgm@ rpm)' '99Nm@ 4500rpm'
#  '170Nm@ 1800-2400rpm' '96Nm@ 2500rpm' '90Nm@ 3500rpm' '84Nm@ 3500rpm'
#  '91Nm@ 4250rpm' '90nm@ 3500rpm' '10.4@ 3,200(kgm@ rpm)' '210 / 1900'
#  '102Nm@ 2600rpm' '10.2@ 2,600(kgm@ rpm)' '10.7@ 2,600(kgm@ rpm)'
#  '96 Nm at 3000 rpm' '96  Nm at 3000  rpm ' '9.8@ 3,000(kgm@ rpm)'
#  '8.6@ 3,500(kgm@ rpm)' '99.8Nm@ 2700rpm' '100Nm@ 2700rpm' '96Nm@ 3000rpm'
#  '18@ 1,600-2,200(kgm@ rpm)' '182.5Nm@ 1500-1800rpm' '180Nm@ 1440-1500rpm'
#  '180 Nm at 1440-1500rpm' '83Nm@ 3000rpm' '90.3Nm@ 4200rpm'
#  '9.2@ 4,200(kgm@ rpm)' '195Nm@ 1440-2200rpm' '96.1Nm@ 3000rpm'
#  '12.5@ 2,500(kgm@ rpm)' '85Nm@ 3000rpm' '85Nm@ 3500rpm' '88.4Nm@ 4200rpm'
#  '78Nm@ 4500rpm' '78Nm@ 3500rpm' '77Nm@ 3500rpm' '789Nm@ 2250rpm'
#  '150Nm@ 1750rpm' '7.8@ 4,500(kgm@ rpm)' '142.5Nm@ 1750rpm'
#  '90Nm@ 2650rpm' '74.5Nm@ 4000rpm' '72Nm@ 4386rpm' '8.5@ 2,500(kgm@ rpm)'
#  '72Nm@ 4388rpm' '71Nm@ 3500rpm' '85Nm@ 2500rpm' '106Nm@ 2200rpm'
#  '69Nm@ 3500rpm' '125Nm@ 2000rpm' '62Nm@ 3000rpm' '98Nm@ 1600-3000rpm'
#  '60Nm@ 3500rpm' '51Nm@ 4000+/-500rpm' '6@ 2,500(kgm@ rpm)'
#  '51Nm@ 4000rpm' '59Nm@ 2500rpm' '62Nm@ 2500rpm' '72.9Nm@ 2250rpm'
#  '5.7@ 2,500(kgm@ rpm)' '6.1kgm@ 3000rpm' '6.1@ 3,000(kgm@ rpm)'
#  '48Nm@ 3000rpm' '48@ 3,000+/-500(NM@ rpm)' '4.8kgm@ 3000rpm'
#  '57Nm@ 2500rpm' nan] - 441

# %%
cols = [col for col in numerical_cols] # a list comprehension, creating a list of numerical columns
print(f'This dataset has {len(cols)} numerical columns - {cols}') #returns the number of numerical columns
# Out:
# This dataset has 7 numerical columns - ['year', 'selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'seats']

# %%
for cols in numerical_cols: #loops through columns
    print(f'- {cols:<14}   - Min value: {df[cols].min():<12}   - Max value: {df[cols].max()}') #returns column name, minimum value and maximum value
# Out:
# - year             - Min value: 1983           - Max value: 2020
# - selling_price    - Min value: 29999          - Max value: 10000000
# - km_driven        - Min value: 1              - Max value: 2360457
# - mileage          - Min value: 0.0            - Max value: 42.0
# - engine           - Min value: 624.0          - Max value: 3604.0
# - max_power        - Min value: 0.0            - Max value: 400.0
# - seats            - Min value: 2.0            - Max value: 14.0

# %% [markdown]
# Definition of Columns
# - name - The model name of the car
# - fuel - The type of fuel used
# - seller type - Who's selling the car
# - transmission - The gear system of the car
# - owner - Ownership history
# - torque - rotational force of the engine
# - year - The manufacturing year of the car
# - selling_price - The selling price of the car
# - km_driven - The number of kilometres the car has been driven
# - mileage - the efficiency of the fuel
# - engine - engine displacement
# - max_power - maximum power output of the engine
# - seats - number of seats available in the car

# %%
#checking for duplicated data, keeping the first occurence
df[df.duplicated(keep='first')] #returns duplicated rows, keeping only the first occurence
# Out:
#                                      name  year  selling_price  km_driven  \
# 3         Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 4         Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 5         Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 6         Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 7         Jeep Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# ...                                   ...   ...            ...        ...
# 8074                Maruti Swift VDI BSIV  2017         525000      38000
# 8114                    Maruti Esteem Lxi  2002          95000      90000
# 8116                   Fiat Palio 1.2 ELX  2003          70000      50000
# 8119  Hyundai Santro Xing XL eRLX Euro II  2006         105000      60000
# 8123               Toyota Qualis Fleet A3  2000         200000     100000
#
#         fuel seller_type transmission         owner  mileage  engine  \
# 3     Petrol  Individual    Automatic   First Owner      9.5  3604.0
# 4     Petrol  Individual    Automatic   First Owner      9.5  3604.0
# 5     Petrol  Individual    Automatic   First Owner      9.5  3604.0
# 6     Petrol  Individual    Automatic   First Owner      9.5  3604.0
# 7     Petrol  Individual    Automatic   First Owner      9.5  3604.0
# ...      ...         ...          ...           ...      ...     ...
# 8074  Diesel      Dealer       Manual  Second Owner      NaN     NaN
# 8114  Petrol  Individual       Manual   Third Owner      NaN     NaN
# 8116  Petrol  Individual       Manual  Second Owner      NaN     NaN
# 8119  Petrol  Individual       Manual   Third Owner      NaN     NaN
# 8123  Diesel  Individual       Manual   First Owner      NaN     NaN
#
#       max_power          torque  seats
# 3         280.0  347Nm@ 4300rpm    5.0
# 4         280.0  347Nm@ 4300rpm    5.0
# 5         280.0  347Nm@ 4300rpm    5.0
# 6         280.0  347Nm@ 4300rpm    5.0
# 7         280.0  347Nm@ 4300rpm    5.0
# ...         ...             ...    ...
# 8074        NaN             NaN    NaN
# 8114        NaN             NaN    NaN
# 8116        NaN             NaN    NaN
# 8119        NaN             NaN    NaN
# 8123        NaN             NaN    NaN
#
# [1202 rows x 13 columns]

# %%
df.drop_duplicates(keep='first',inplace=True) #drops all duplicated rows, keeping only the first occurence

# %%
# +1: strong positive correlation (as one increases, the other increases)
# -1: strong negative correlation (as one increases, the other decreases)
# 0: no correlation

corr = df.corr(method='spearman',numeric_only=True) #calculates correlation of numeric data using the spearman method
#plotting correlation using a heatmap
plt.rcParams['figure.figsize'] = (15,10)
sns.heatmap(data=corr,annot=True,linewidths=1,fmt='.2f')
plt.title('Correlation HeatMap of Numeric Features',fontsize = 20)
plt.show()

# %%
df.drop(columns=['torque'],inplace=True) #drops the torque column

# %%
#checking for missing data
missing = df.isnull().sum().sort_values(ascending=False) #sums all null values for each columns
missing_pct = missing / len(df) * 100 #calculates missing values as a percentage of rows in the data
miss = pd.DataFrame({
    'missing values' :missing,
    'Missing Pct': missing_pct
})
print(miss) #returns missing values and missing percentages as a dataframe
# Out:
#                missing values  Missing Pct
# seats                     208     3.003176
# mileage                   208     3.003176
# engine                    208     3.003176
# max_power                 206     2.974300
# km_driven                   0     0.000000
# selling_price               0     0.000000
# year                        0     0.000000
# name                        0     0.000000
# owner                       0     0.000000
# transmission                0     0.000000
# seller_type                 0     0.000000
# fuel                        0     0.000000

# %%
#plotting boxplots to reveal outliers
plt.subplots(1,4,figsize=(25,10))
plt.subplot(141)
sns.boxplot(data=df,y='mileage',color='red',linewidth=3)
plt.title('Mileage')

plt.subplot(142)
sns.boxplot(data=df,y='km_driven',color='yellow',linewidth=3)
plt.title('KM driven')

plt.subplot(143)
sns.boxplot(data=df,y='max_power',color='green',linewidth=3)
plt.title('Max power')

plt.subplot(144)
sns.boxplot(data=df,y='engine',color='blue',linewidth=3)
plt.title('engine')
plt.show()

# %%
#plotting pariplots to reveal relationships
sns.pairplot(data=df)

# %%
#performing analysis on categorical data
plt.rcParams['figure.figsize'] =(20,10)
plt.subplot(1,4,1)
size = df['fuel'].value_counts() #counts all the values in the column
labels = df['fuel'].unique() #returns unique values in the column
colors = ['red','yellow','green','blue']
plt.title('Fuel')
plt.pie(size,labels=labels,colors=colors, autopct='%2f%%',shadow=True,explode=[0.1,0.1,0.1,0.1]) #plotting a pie chart

plt.subplot(1,4,2)
size = df['owner'].value_counts()
labels = df['owner'].unique()
colors = ['red','yellow','green','blue','pink']
plt.title('Owner')
plt.pie(size,labels=labels,colors=colors, autopct='%2f%%',shadow=True)

plt.subplot(1,4,3)
size = df['seller_type'].value_counts()
labels = df['seller_type'].unique()
colors = ['red','yellow','green','blue']
plt.title('Seller Type')
plt.pie(size,labels=labels,colors=colors, autopct='%2f%%',shadow=True,explode=[0.1,0.1,0.1])

plt.subplot(1,4,4)
size = df['transmission'].value_counts()
labels = df['transmission'].unique()
colors = ['yellow','green','blue']
plt.title('Transmission')
plt.pie(size,labels=labels,colors=colors, autopct='%2f%%',shadow=True,explode=[0.1,0.1])
plt.show()

# %% [markdown]
# - Insights

# %%
#analyzing the target output
print(df['selling_price'].skew())
# Out:
# 5.572742292649191

# %%
#transforming target column to handle skewness
df['selling_price_scaled'] = np.log1p(df['selling_price'])

# %%
#plotting target output, before and after log-transformations
plt.figure(figsize=(20,9))
plt.subplot(1,2,1)
sns.histplot(df['selling_price'],kde=True,bins=20,color='pink')

plt.subplot(1,2,2)
sns.histplot(df['selling_price_scaled'],kde=True,bins=20)
plt.tight_layout()
plt.show()

# %%
df.to_csv('data/processed_df.csv')
